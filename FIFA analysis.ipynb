# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ### Read csv File

# %%
df=pd.read_csv("players_22.csv", low_memory=False)
df.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5     200389  https://sofifa.com/player/200389/jan-oblak/220002
# 6     231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8     192448  https://sofifa.com/player/192448/marc-andre-te...
# 9     202126  https://sofifa.com/player/202126/harry-kane/22...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# ...

# %%
#view all columns

# %%
pd.set_option("display.max_columns",None)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age         dob  height_cm  \
# ...

# %% [markdown]
# ### Drop unneccsary column

# %%
df=df.drop(["sofifa_id","player_url","long_name","dob","height_cm","weight_kg","club_team_id",
         "league_level","club_position","club_jersey_number","club_loaned_from","club_joined","club_contract_valid_until",
         "nationality_id","nation_team_id","nation_jersey_number","body_type","real_face",
         "release_clause_eur","player_tags","player_traits","player_face_url","club_logo_url","club_flag_url",
         "nation_logo_url","nation_flag_url","ls","st","rs","lw","lf","rf","rw","lam","cam","lm",
          "lcm","cm","rcm","rm","lwb","ldm","rdm","rwb","lb","lb","lcb","cb","rcb","rb","rb","gk",
           "cf","ram","cdm"],axis=1)
df.head()
# Out:
#           short_name player_positions  overall  potential    value_eur  \
# 0           L. Messi       RW, ST, CF       93         93   78000000.0
# 1     R. Lewandowski               ST       92         92  119500000.0
# 2  Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 3          Neymar Jr          LW, CAM       91         91  129000000.0
# 4       K. De Bruyne          CM, CAM       91         91  125500000.0
#
#    wage_eur  age            club_name             league_name  \
# 0  320000.0   34  Paris Saint-Germain          French Ligue 1
# 1  270000.0   32    FC Bayern München    German 1. Bundesliga
# 2  270000.0   36    Manchester United  English Premier League
# 3  270000.0   29  Paris Saint-Germain          French Ligue 1
# 4  350000.0   30      Manchester City  English Premier League
#
#   nationality_name nation_position preferred_foot  weak_foot  skill_moves  \
# 0        Argentina              RW           Left          4            4
# ...

# %% [markdown]
# ### Now we will consider teams which are qualifies into worldcup.

# %%
teams_worldcup = [
    'Qatar', 'Brazil', 'Belgium', 'France', 'Argentina', 'England', 'Spain', 'Portugal',
    'Mexico', 'Netherlands', 'Denmark', 'Germany', 'Uruguay', 'Switzerland', 'United States', 'Croatia',
    'Senegal', 'Iran', 'Japan', 'Morocco', 'Serbia', 'Poland', 'South Korea', 'Tunisia',
    'Cameroon', 'Canada', 'Ecuador', 'Saudi Arabia', 'Ghana', 'Wales', 'Costa Rica', 'Australia']
df = df[df['nationality_name'].isin(teams_worldcup)]
df
# Out:
#               short_name player_positions  overall  potential    value_eur  \
# 0               L. Messi       RW, ST, CF       93         93   78000000.0
# 1         R. Lewandowski               ST       92         92  119500000.0
# 2      Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 3              Neymar Jr          LW, CAM       91         91  129000000.0
# 4           K. De Bruyne          CM, CAM       91         91  125500000.0
# ...                  ...              ...      ...        ...          ...
# 19183         F. Emmings               GK       48         73     130000.0
# 19197            J. Neal               CB       48         69     140000.0
# 19216  H. Wiles-Richards               GK       48         65     110000.0
# 19217         J. Affonso               CM       48         55      90000.0
# 19230          N. Saliba               CM       47         69     150000.0
#
# ...

# %%
rows,columns=df.shape

# %%
columns
# Out:
# 57

# %%
rows
# Out:
# 12266

# %%
df.describe()
# Out:
#             overall     potential     value_eur       wage_eur           age  \
# count  12266.000000  12266.000000  1.224600e+04   12256.000000  12266.000000
# mean      66.424833     71.875591  3.280923e+06   10254.361129     25.059922
# std        6.763040      5.876304  8.473582e+06   21627.722021      4.730115
# min       47.000000     55.000000  1.500000e+04     500.000000     16.000000
# 25%       62.000000     68.000000  5.250000e+05    2000.000000     21.000000
# 50%       66.000000     72.000000  1.100000e+06    3000.000000     24.000000
# 75%       71.000000     76.000000  2.300000e+06   10000.000000     28.000000
# max       93.000000     95.000000  1.940000e+08  350000.000000     54.000000
#
#           weak_foot   skill_moves  international_reputation          pace  \
# count  12266.000000  12266.000000              12266.000000  10894.000000
# mean       2.966248      2.365074                  1.108022     68.187534
# ...

# %%
df.describe(include="O")
# Out:
#           short_name player_positions   club_name                 league_name  \
# count          12266            12266       12256                       12256
# unique         11663              581         687                          55
# top     J. Rodríguez               CB  Sevilla FC  Argentina Primera División
# freq               9             1556          32                         680
#
#        nationality_name nation_position preferred_foot      work_rate
# count             12266             368          12266          12266
# unique               30              25              2              9
# top             England             SUB          Right  Medium/Medium
# freq               1719             192           9305           6457

# %% [markdown]
# ### Data Cleaning.

# %%
df.ffill(axis=0)
# Out:
#               short_name player_positions  overall  potential    value_eur  \
# 0               L. Messi       RW, ST, CF       93         93   78000000.0
# 1         R. Lewandowski               ST       92         92  119500000.0
# 2      Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 3              Neymar Jr          LW, CAM       91         91  129000000.0
# 4           K. De Bruyne          CM, CAM       91         91  125500000.0
# ...                  ...              ...      ...        ...          ...
# 19183         F. Emmings               GK       48         73     130000.0
# 19197            J. Neal               CB       48         69     140000.0
# 19216  H. Wiles-Richards               GK       48         65     110000.0
# 19217         J. Affonso               CM       48         55      90000.0
# 19230          N. Saliba               CM       47         69     150000.0
#
# ...

# %% [markdown]
# ### Sort Data-table by overall and potential value.

# %%
df.sort_values(by=['overall', 'potential'], ascending=False, inplace=True)
df
# Out:
#               short_name player_positions  overall  potential    value_eur  \
# 0               L. Messi       RW, ST, CF       93         93   78000000.0
# 1         R. Lewandowski               ST       92         92  119500000.0
# 6              K. Mbappé           ST, LW       91         95  194000000.0
# 2      Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 3              Neymar Jr          LW, CAM       91         91  129000000.0
# ...                  ...              ...      ...        ...          ...
# 19183         F. Emmings               GK       48         73     130000.0
# 19197            J. Neal               CB       48         69     140000.0
# 19216  H. Wiles-Richards               GK       48         65     110000.0
# 19217         J. Affonso               CM       48         55      90000.0
# 19230          N. Saliba               CM       47         69     150000.0
#
# ...

# %% [markdown]
# ### Find The Best Player From Each Nation.

# %%
df_best_players = df.copy()
df_best_players = df_best_players.drop_duplicates('nationality_name').reset_index(drop=True)

# %% [markdown]
# ### Visulization for Best Players.

# %%
fig, ax = plt.subplots(figsize=(14, 6), tight_layout=True)
sns.barplot(x="overall",y="short_name", data=df_best_players)
# Out:
# <AxesSubplot:xlabel='overall', ylabel='short_name'>

# %% [markdown]
# ###  Observation: Messi is best player among all best player country wise

# %% [markdown]
# ### In which Football league players play most?

# %%
# Here we consider top 200 player only

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="league_name", data=df.head(200))
plt.xticks(rotation=90)
plt.xlabel("league Name")
plt.ylabel("Count name")
plt.show()

# %% [markdown]
# ### observation:In top 200 player, Most player play in English premier League

# %%
plt.figure(figsize=(14,6))
sns.countplot(x="club_name", data=df.head(200),palette="Paired")
plt.xticks(rotation=90)
plt.xlabel("top 200 player club wise",)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Observation: Manchester City team have highest player in top 200.

# %%
plt.figure(figsize=(14,6))
sns.countplot(x="nationality_name", data=df.head(200),palette="Paired")
plt.xticks(rotation=90)
plt.xlabel("top 200 player country wise",)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Observation: spanish players are highest in Top 200 player.

# %% [markdown]
# ### Which country have highest Right footer player?

# %%
plt.figure(figsize=(14,5))
ax=sns.countplot(x="nationality_name",hue='preferred_foot',data=df)
plt.xticks(rotation=90)
ax.set(title="Nationality v/s preferred_foot ")
plt.xlabel('nationality',size=12)
plt.ylabel('Count',size=12)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Observation: England have Highest Right Footer player

# %% [markdown]
# ### Top 10 expensive player by market value.

# %%
expensive_player=df.groupby(["short_name"])[["value_eur"]].sum().reset_index()
expensive_player.head(5)
# Out:
#      short_name  value_eur
# 0       A. Abaz   120000.0
# 1       A. Abdi  1700000.0
# 2  A. Abedzadeh  2400000.0
# 3      A. Abqar   700000.0
# 4    A. Acevedo   100000.0

# %%
expensive_player.sort_values(by=['value_eur'], ascending=False, inplace=True)
expensive_player.head(10)
# Out:
#                 short_name    value_eur
# 5960             K. Mbappé  194000000.0
# 4030               H. Kane  131400000.0
# 8506             Neymar Jr  129000000.0
# 5817          K. De Bruyne  125500000.0
# 3461            F. de Jong  119500000.0
# 9349        R. Lewandowski  119500000.0
# 5282             J. Sancho  116500000.0
# 10432  T. Alexander-Arnold  114000000.0
# 4946            J. Kimmich  108000000.0
# 9503           R. Sterling  107500000.0

# %%
# Converting the value into million.

# %%
expensive_player.value_eur = (expensive_player.value_eur.astype(float)/1000000).astype(str) + 'M'
expensive_player.head(10)
# Out:
#                 short_name value_eur
# 5960             K. Mbappé    194.0M
# 4030               H. Kane    131.4M
# 8506             Neymar Jr    129.0M
# 5817          K. De Bruyne    125.5M
# 3461            F. de Jong    119.5M
# 9349        R. Lewandowski    119.5M
# 5282             J. Sancho    116.5M
# 10432  T. Alexander-Arnold    114.0M
# 4946            J. Kimmich    108.0M
# 9503           R. Sterling    107.5M

# %% [markdown]
# ### Which league have higest market value?

# %%
expensive_league=df.groupby(["league_name"])[["value_eur"]].sum().reset_index().sort_values("value_eur", ascending=False)
expensive_league.head(10)
# Out:
#                       league_name     value_eur
# 17         English Premier League  7.471630e+09
# 45         Spain Primera Division  6.608850e+09
# 21           German 1. Bundesliga  3.779230e+09
# 19                 French Ligue 1  3.490570e+09
# 28                Italian Serie A  2.625975e+09
# 38     Portuguese Liga ZON SAGRES  1.729720e+09
# 4   Campeonato Brasileiro Série A  1.394130e+09
# 0      Argentina Primera División  1.290605e+09
# 25             Holland Eredivisie  1.194455e+09
# 46       Spanish Segunda División  1.028720e+09

# %%
# now to convert into value into Million

# %%
expensive_league.value_eur = (expensive_league.value_eur.astype(float)/1000000).astype(str) + 'M'

# %%
expensive_league.head(10)
# Out:
#                       league_name  value_eur
# 17         English Premier League   7471.63M
# 45         Spain Primera Division   6608.85M
# 21           German 1. Bundesliga   3779.23M
# 19                 French Ligue 1   3490.57M
# 28                Italian Serie A  2625.975M
# 38     Portuguese Liga ZON SAGRES   1729.72M
# 4   Campeonato Brasileiro Série A   1394.13M
# 0      Argentina Primera División  1290.605M
# 25             Holland Eredivisie  1194.455M
# 46       Spanish Segunda División   1028.72M

# %% [markdown]
# ### Observation: English Premier League have Higest value.

# %% [markdown]
# ### Which player position get Highest average pay?

# %%
df['player_pos'] = df.player_positions.str.split(',').str[0]
df.drop(columns='player_positions',inplace=True)

# %%
avg_pay = df.groupby("player_pos")['wage_eur'].mean().round(2)
axes = avg_pay.plot(kind='bar', x='avg_pay', y="player_pos",figsize=(11,6));
axes.set_ylabel('ave_pay')
axes.set_title("Player Positions and their Pay");

# %% [markdown]
# ### Observation: Central forward position have highest pay.

# %% [markdown]
# ### which country player get highest wage?

# %%
high_wage=df.groupby(["nationality_name"])["wage_eur"].mean().sort_values(ascending=False)
high_wage.head(10).round(2)
# Out:
# nationality_name
# Brazil      16266.22
# Spain       14599.22
# Senegal     14390.16
# Belgium     14214.22
# Portugal    13966.62
# Croatia     13317.53
# France      13164.39
# Serbia      13001.22
# Morocco     12904.46
# Cameroon    12713.85
# Name: wage_eur, dtype: float64

# %%
high_wage.plot(kind="bar",figsize=(11,6))
plt.xlabel("Countries")
plt.ylabel("Average_wage")
plt.title("Average_wage Country wise")
# Out:
# Text(0.5, 1.0, 'Average_wage Country wise')

# %% [markdown]
# ### Observation: Brazilan player get Highest wage.

# %% [markdown]
# ### Which club team give  highest wages?

# %%
high_wage=df.groupby(["club_name"])["wage_eur"].mean().sort_values(ascending=False)
high_wage.head(10).round(2)
# Out:
# club_name
# Real Madrid CF         134166.67
# Manchester United      110285.71
# Manchester City        109846.67
# FC Barcelona           100750.00
# Liverpool               95148.15
# Chelsea                 93366.67
# Paris Saint-Germain     88225.81
# Inter                   84416.67
# Juventus                83583.33
# FC Bayern München       71333.33
# Name: wage_eur, dtype: float64

# %%
high_wage.head(10).plot(kind="bar",figsize=(11,6))
plt.xlabel("Countries")
plt.ylabel("Average_wage")
plt.title("Average_wage club wise")
# Out:
# Text(0.5, 1.0, 'Average_wage club wise')

# %% [markdown]
# ### Observation: Real Madrid CF give highest wages

# %% [markdown]
# ### Which team is youngest team?

# %%
age=df.groupby(["nationality_name"])["age"].mean().sort_values(ascending=True)
age.head(10).round(2)
# Out:
# nationality_name
# Netherlands      23.94
# Wales            24.09
# Belgium          24.18
# Denmark          24.21
# Canada           24.22
# England          24.27
# Poland           24.32
# United States    24.37
# Australia        24.44
# Switzerland      24.44
# Name: age, dtype: float64

# %% [markdown]
# ### Observation: Netherland team is youngest Team

# %% [markdown]
# ### Which Team Player good at passing the ball?

# %%
pass_ball=df.groupby(["nationality_name"])["passing"].mean().sort_values(ascending=False)
pass_ball.head(10).round(2)
# Out:
# nationality_name
# Spain          62.27
# Morocco        62.07
# Brazil         61.70
# Portugal       61.61
# Iran           60.88
# Tunisia        60.53
# Belgium        60.50
# Costa Rica     60.27
# Argentina      60.19
# Netherlands    59.72
# Name: passing, dtype: float64

# %% [markdown]
# ### Observation: Spanish players Good at passing ball

# %% [markdown]
# ### Which team player good  at defending?

# %%
defend=df.groupby(["nationality_name"])["defending"].mean().sort_values(ascending=False)
defend.head(10).round(2)
# Out:
# nationality_name
# Croatia        56.00
# Spain          54.89
# Netherlands    54.87
# Portugal       54.86
# Mexico         54.56
# Cameroon       54.40
# Serbia         54.17
# France         53.84
# Brazil         53.33
# Switzerland    53.23
# Name: defending, dtype: float64

# %% [markdown]
# ### Obeservation: Crotian player are good at defending.

# %% [markdown]
# ### Best Top 10 CF Players

# %%
df[df.player_pos == 'CF'].head(10)
# Out:
#            short_name  overall  potential   value_eur  wage_eur  age  \
# 11         K. Benzema       89         89  66000000.0  350000.0   33
# 41          P. Dybala       87         88  93000000.0  160000.0   27
# 86           M. Depay       85         86  63000000.0  220000.0   27
# 85    Roberto Firmino       85         85  54000000.0  185000.0   29
# 100        D. Mertens       84         84  20500000.0  105000.0   34
# 198        João Félix       83         91  82000000.0   61000.0   21
# 246  Anderson Talisca       82         83  35500000.0   61000.0   27
# 346         J. Correa       81         82  31000000.0   76000.0   26
# 298          M. Kruse       81         81  16500000.0   45000.0   33
# 423        João Pedro       80         80  21000000.0   46000.0   29
#
#               club_name                   league_name nationality_name  \
# 11       Real Madrid CF        Spain Primera Division           France
# ...

# %% [markdown]
# ### Top 10 Goal keeper

# %%
df[df.player_pos == 'GK'].head(10)
# Out:
#        short_name  overall  potential   value_eur  wage_eur  age  \
# 8   M. ter Stegen       90         92  99000000.0  250000.0   29
# 7        M. Neuer       90         90  13500000.0   86000.0   35
# 12    T. Courtois       89         91  85500000.0  250000.0   29
# 18        Ederson       89         91  94000000.0  200000.0   27
# 20        Alisson       89         90  82000000.0  190000.0   28
# 26       K. Navas       88         88  15500000.0  130000.0   34
# 31      H. Lloris       87         87  13500000.0  125000.0   34
# 34    W. Szczęsny       87         87  42000000.0  105000.0   31
# 54    K. Casteels       86         87  52000000.0   88000.0   29
# 70  K. Schmeichel       85         85   9000000.0  115000.0   34
#
#               club_name             league_name nationality_name  \
# 8          FC Barcelona  Spain Primera Division          Germany
# 7     FC Bayern München    German 1. Bundesliga          Germany
# ...

# %% [markdown]
# ### Which player positions have highest workrate

# %%
work_rate=df.groupby("work_rate")["player_pos"].max()
work_rate
# Out:
# work_rate
# High/High         ST
# High/Low          ST
# High/Medium       ST
# Low/High         RWB
# Low/Low           ST
# Low/Medium       RWB
# Medium/High       ST
# Medium/Low        ST
# Medium/Medium     ST
# Name: player_pos, dtype: object

# %% [markdown]
# ### Observation: ST(striker) positon have highest workload, also notice that Striker position also get highest wage.
